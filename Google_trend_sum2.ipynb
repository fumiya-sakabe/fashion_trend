# %% [markdown]
# <a href="https://colab.research.google.com/github/fumiya-sakabe/fashion_trend/blob/main/Google_trend_sum2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/Fashion_Trend/Tops_coat_trend.csv')

df.head()
# Out:
#          月 チェスターコート Pコート トレンチコート
# 0  2004-01        1   10      13
# 1  2004-02        0    3       9
# 2  2004-03        0    1       9
# 3  2004-04        0    0       5
# 4  2004-05        0    0       0

# %%
df['月'] = pd.to_datetime(df['月'])

# %%
def month_to_season(month):
    if month == 1 or month == 2 or month == 12:
        return 'winter'
    elif month == 3 or month == 4 or month == 5:
        return 'spring'
    elif month == 6 or month == 7 or month == 8:
        return 'summer'
    else:
        return 'autumn'

# %%
df['only_month'] = df['月'].dt.month
df['season'] = df['only_month'].apply(month_to_season)

# %%
df
# Out:
#              月 チェスターコート Pコート トレンチコート  only_month  season  Year
# 0   2004-01-01        1   10      13           1  winter  2004
# 1   2004-02-01        0    3       9           2  winter  2004
# 2   2004-03-01        0    1       9           3  spring  2004
# 3   2004-04-01        0    0       5           4  spring  2004
# 4   2004-05-01        0    0       0           5  spring  2004
# ..         ...      ...  ...     ...         ...     ...   ...
# 237 2023-10-01        7    3      20          10  autumn  2023
# 238 2023-11-01       17    6      23          11  autumn  2023
# 239 2023-12-01       20    6      17          12  winter  2023
# 240 2024-01-01       14    4      15           1  winter  2024
# 241 2024-02-01       10    3      18           2  winter  2024
#
# [242 rows x 7 columns]

# %%
type(df.loc[1, 'トレンチコート'])
# Out:
# numpy.int64

# %%
df['トレンチコート'] = df['トレンチコート'].astype('int')
df['Pコート'] = df['Pコート'].astype('int')
df['チェスターコート'] = df['チェスターコート'].astype('int')

# %%
df['season'] = pd.Categorical(df['season'], categories=['winter', 'spring', 'summer', 'autumn'], ordered=True)

# %%
df['Year'] = df['月'].dt.year

# %%
df.replace({"チェスターコート": {"1 未満": 0},"Pコート": {"1 未満": 0},"トレンチコート": {"1 未満": 0}}, inplace=True)

# %%
df_pivot = df.pivot_table(index=['Year', 'season'], values=df.columns[1:4], aggfunc='mean')

# %%
df_pivot
# Out:
#                  Pコート   チェスターコート    トレンチコート
# Year season
# 2004 winter  7.333333   1.333333  12.333333
#      spring  0.333333   0.000000   4.666667
#      summer  0.000000   1.000000   1.333333
#      autumn  5.666667   1.000000  13.000000
# 2005 winter  7.000000   1.666667  12.666667
# ...               ...        ...        ...
# 2023 winter  4.333333  16.333333  22.000000
#      spring  0.666667   2.333333  25.333333
#      summer  0.333333   1.333333   3.666667
#      autumn  3.333333   9.000000  17.333333
# 2024 winter  3.500000  12.000000  16.500000
#
# [81 rows x 3 columns]

# %%
growth_rate = df_pivot.pct_change(1).dropna()

# %%
growth_rate
# Out:
#                  Pコート  チェスターコート   トレンチコート
# Year season
# 2004 spring -0.954545 -1.000000 -0.621622
#      summer -1.000000       inf -0.714286
#      autumn       inf  0.000000  8.750000
# 2005 winter  0.235294  0.666667 -0.025641
#      spring -0.952381 -0.800000 -0.526316
# ...               ...       ...       ...
# 2023 winter  0.300000  0.400000  0.118644
#      spring -0.846154 -0.857143  0.151515
#      summer -0.500000 -0.428571 -0.855263
#      autumn  9.000000  5.750000  3.727273
# 2024 winter  0.050000  0.333333 -0.048077
#
# [80 rows x 3 columns]

# %%
trending_items = growth_rate.idxmax(axis=1).reset_index()
trending_items.columns = ['Year', 'season', 'Trending Item']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-dd5960f2f876> in <cell line: 1>()
# ----> 1 trending_items = growth_rate.idxmax(axis=1).reset_index()
#       2 trending_items.columns = ['Year', 'season', 'Trending Item']
#
# NameError: name 'growth_rate' is not defined

# %%
trending_items
# Out:
#     Year  season Trending Item
# 0   2004  spring       トレンチコート
# 1   2004  summer      チェスターコート
# 2   2004  autumn          Pコート
# 3   2005  winter      チェスターコート
# 4   2005  spring       トレンチコート
# ..   ...     ...           ...
# 75  2023  winter      チェスターコート
# 76  2023  spring       トレンチコート
# 77  2023  summer      チェスターコート
# 78  2023  autumn          Pコート
# 79  2024  winter      チェスターコート
#
# [80 rows x 3 columns]

# %%
trending_items.to_csv('/content/drive/MyDrive/Fashion_Trend/Tops_coat_trend_calu.csv', encoding='shift-jis', index = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2206866d4688> in <cell line: 1>()
# ----> 1 trending_items.to_csv('/content/drive/MyDrive/SAMURAI TERAKOYA 最終課題/Tops_coat_trend_calu.csv', encoding='shift-jis', index = False)
#
# NameError: name 'trending_items' is not defined
