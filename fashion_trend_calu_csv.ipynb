# %% [markdown]
# <a href="https://colab.research.google.com/github/fumiya-sakabe/fashion_trend/blob/main/fashion_trend_calu_csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
